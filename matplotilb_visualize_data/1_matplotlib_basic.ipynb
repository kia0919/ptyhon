# %% [markdown]
# ### 데이터 시각화 패키지 맷플롯리브
# matplotlib 패키지는 파이선에서 데이터를 차트 혹은 플롯으로 시각화하는 패키지
# - 선형 그래프(line plot)
# - 점 그래프(scatter plot)
# - 등고선(contour plot)
# - 표면도(surface plot)
# - 막대 그래프(bar chart)
# - 히스토그램(histogram)
# - 박스 그래프(box plot)

# %% [markdown]
# ### `pyplot` 하위 패키지
# 간단한 시각화 자료를 만들때 사용되는 matplotlib의 하위 패키지
# matplotlib 패키지를 직접 사용하지 않고 단순히 pyplot 만으로 시각화를 할 수 있음

# %% [markdown]
# ```python
# import matplotlib as mpl
# import matplotlib.pyplot as plt
# ```
# ```bash
# pip install seaborn
# ```

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
# matplotlib 한글 표시 설정
import matplotlib.font_manager as fm

# matplotlib의 글꼴 관리자에 특정 글꼴 추가
fe = fm.FontEntry(
    fname=r'font/NanumGothic.ttf',
    name= 'NanumGothic'
)
fm.fontManager.ttflist.insert(0, fe)

# pyplot에 matplotlib의 글골 관지라에 등록된 글꼴 적용
plt.rcParams.update({ 'font.family': 'NanumGothic', 'font.size': 14 })

# pyplot에서 '-' 를 문자로 취급하도록 설정
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# ### 차트의 종류
#
# **막대 그래프** : 데이터의 카테고리 별  값을 막대로 나타내는 방식(수직 막대 그래프. 수평 막대 그래프)
# > 카테고리별로 비교할 대 주로 사용됨(제품별 판매량, 지역별 인구수)
#
# **선 그래프**: 시간의 흐름에 따른  데이터 포인터를 선으로 연결하여 나타내는 방식
# > 시간의 흐름에 따라 비교할 때 주로 사용됨 (기온의 변화, 주식 가격)
#
# **파이 차트**: 전체에 대한 비율을 원형으로 나타내는 방식 (각 조각의 크기가 해당 부분의 비율)
# > 전체에 대한 비율을 비교할 때 주로 사용됨 (여론조사 결과)
#
# **산점도**: 두 변수 간의 상관 관계를 점들의 분포로 나타내는 방식
# > 두 변수의 상관 관계를 파악할 때 주로 사용됨(키와 몸무게의 상관관계, )
#
# **히스토그램**: 범위별로 그룹화해서 각 그룹에 속하는 데이터 포인터의 수를 막대로 나타내는 방식
# > 데이터의 분포를 비교할 때 주로 사용됨 (시험 점수의 분포)
#
# **영역 그래프**: 선 그래프의 아래 영역에 색으로 채운 형태
# > 시간의 흐름에 따라 비교할 때 주로 사용됨, 변화량을 강조할 때 주로 사용됨 (누적 감염자, 누적 수출량)
#
# **박스 그래프**: 데이터의 분포를 나타내는 방식, 최소값, 최대값, 사분위수를 나타내는 방식
# > 데이터의 이상치를 판단할 대 주로 사용됨 ()

# %% [markdown]
# ### 라인 플롯 (선 그래프)
# 가장 기본적인 그래프로 데이터가 시간의 흐름, 순서에 따라 변할 때 사용됨
# `pyplot`하위 패키지의 `plot()` 메서드로 간단하게 생성 가능, 매개변수로 리스트 혹은 배열을 전달

# %%
plt.plot([1, 2, 4, 8, 16, 32])
plt.show()

# %%
plt.title('x 대박')
plt.plot([2000, 2005, 2010, 2015, 2020, 2025], [1, 2, 4, 8, 16, 32])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 48149 (\N{HANGUL SYLLABLE BAG}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ### 차트 스타일 지정
# `plot()` 메서드에 특정한 문자열 매개변수를 전달하면 스타일을 변경할 수 있음

# %%
plt.title('rs-- 스타일 지정')   # 그래프의 선 모양을 -- 점선으로 바꿈
plt.plot([2000, 2005, 2010, 2015, 2020, 2025], [1, 2, 4, 8, 16, 32], 'rs--')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
plt.title('색깔-- 스타일 지정')   # 그래프의 선 모양을 cs색깔지정, -- 점선으로 바꿈
                                    
                                     # s 필수 각 포인트 지점 표시 해줌, 앞에는 색깔. y= yellow_
plt.plot([2000, 2005, 2010, 2015, 2020, 2025], [1, 2, 4, 8, 16, 32], 'ys--')   
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 49353 (\N{HANGUL SYLLABLE SAEG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 44628 (\N{HANGUL SYLLABLE GGAL}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49353 (\N{HANGUL SYLLABLE SAEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ### `plot()` 메서드의 스타일 매개변수
# - color(c): 선 색깔
# - linewidth(lw): 선 굵기
# - linestyle(ls): 선 스타일
# - marker: 마커 종류
# - markersize (ms): 마커 크기
# - markeredgecolor (mec): 마커 테두리 색상
# - markeredgewidth (mew):  마커 테두리 굵기
# - markerfacecolor (mfc): 마커 내부 색상

# %%
plt.title('스타일 지정') # 해당 차트의 제목: 스타일 지정
# x축 범위를 2000~2025, 데이터 값이: 1,2,4,8,16, 32/ lw(선굵기):5, c(선 색갈 번호), ls(선 스타일)을 : 으로 지정, 마커 종류를 * 별모양으로
# ms(마커크기): 10, mfc(마커내부 색깔).
plt.plot([2000, 2005, 2010, 2015, 2020, 2025], [1, 2, 4, 8, 16, 32], lw=5, c='#00998050', ls=':', marker='*', ms=10,
         mfc='#009988')
plt.show()
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.

# %% [markdown]
# ### 차트 범위 지정
# `xlim()`, `ylim()` 메서드로 x축과  y축의 상하한 값을 지정할 수 있음

# %%
plt.title('차트 범위 변경')
plt.plot([2000, 2005, 2010, 2015, 2020, 2025], [1, 2, 4, 8, 16, 32],
               lw=5, c='#00998050', ls=':', marker='*', ms=10, mfc='#009988')
# xlim으로  x축 범위의 최소값, 최대값을 지정
plt.xlim(1995, 2030)
# ylim으로 y축 범위의 최소값, 최대값 지정
plt.ylim(-1, 40)
plt.show()
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.

# %% [markdown]
# ### 틱 설정
# `xticks()`, `yticks()` 메서드로 틱의 위치나 라벨을 직접 지정할 수 있음

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)

plt.title('틱 설정')
plt.plot(X, C) # X, C 시각화
# xticks로 x축 범위 지정 및 위치를 수동으로 지정
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
# xticks와 마찬가지로 수동 지정
plt.yticks([-1, 0, 1], ['low', 'zero', 'high'])
# Out:
# ([<matplotlib.axis.YTick at 0x1b2d1edc140>,
# ...
#  [Text(0, -1, 'low'), Text(0, 0, 'zero'), Text(0, 1, 'high')])
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 54001 (\N{HANGUL SYLLABLE TIG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# ...

# %% [markdown]
# ### Grid 설정
# `grid()` 메서드로 그리드를 표현할지 말지를 정할 수 있음

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)

plt.title('틱 설정')
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, 1], ['low', 'zero', 'high'])
plt.grid(True)
plt.show()
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54001 (\N{HANGUL SYLLABLE TIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.

# %% [markdown]
# ### 여러 그래프르 하나의 차트에 표현하기
# `plot()` 메서드에 x, y, style 매개변수를 반복해서 전달하여 여러 그래프를 하나에 차트에 표현할 수 있음(스타일 문자열 생략 불가능)

# %%
t = np.arange(0., 5., 0.2)
plt.title('여러 그래프 표현')
plt.plot(t, t, 'r--', t, 0.5 * t ** 2, 'bs:', t, 0.2*t **3, 'g^-')
plt.grid(True)
plt.show()
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47084 (\N{HANGUL SYLLABLE REO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ### 차트 겹치기
# `plot()` 메서드를 중복해서 작성하여 차트를 겹칠 수 있음

# %%
# 겹치는 차트의 x축, y축 범위가 다르면 겹쳐지지 않음, 에러 뜸
plt.title('차트 겹치기')
# 차트 한개 만듬
plt.plot([2000, 2005, 2010, 2015, 2020, 2025], [1, 2, 4, 8, 16, 32],
               lw=5, c='#00998050', ls=':', marker='*', ms=10, mfc='#009988')

# 다른 차트 한개 만듬.
plt.plot([2000, 2005, 2010, 2015, 2020, 2025], [32, 16, 8, 4, 2, 1],
               lw=5, c='#99880050', ls=':', marker='o', ms=10, mfc='#998800')
plt.show()
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44217 (\N{HANGUL SYLLABLE GYEOB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ### 범례
# 여러 개의 그래프가 한 차트에 표시 될 때 각 그래프가 무엇을 의미하는 보여주는 범례를 표현할 수 있음
# `legend()` 메서드로 표현(`plot()`메서드에 `label`매개변수를 지정해야 함), 위치를 수동으로 지정하고 싶으면 `loc` 매개변수를 사용함

# %%
plt.title('범례 표현')
# 다음과 같이 차트를 여러개 만들고 차트를 구별하기 위해 사용함.
plt.plot([2000, 2005, 2010, 2015, 2020, 2025], [1, 2, 4, 8, 16, 32],
               lw=5, c='#00998050', ls=':', marker='*', ms=10, mfc='#009988', label= '증가' )

plt.plot([2000, 2005, 2010, 2015, 2020, 2025], [32, 16, 8, 4, 2, 1],
               lw=5, c='#99880050', ls=':', marker='o', ms=10, mfc='#998800', label= '감소')

# 보통 범례의 위치는 자동 지정되지만, legend메서드 인수에 loc 사용 시 수동 지정 가능
plt.show()
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48276 (\N{HANGUL SYLLABLE BEOM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47168 (\N{HANGUL SYLLABLE RYE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.

# %% [markdown]
# ### x축, y축 라벨
# `xlabel()`, `ylabel()` 메서드로 x축과 y축의 라벨을 표시할 수 있음

# %%
# x축, y축이 무엇을 의미하는지 표시하는 것.
# 타이틀은 한국어 패키지 실행없이 되지만 라벨은 필수로 실행시켜야 함.
plt.title('각 축 라벨 표현')

plt.plot([2000, 2005, 2010, 2015, 2020, 2025], [1, 2, 4, 8, 16, 32],
               lw=5, c='#00998050', ls=':', marker='*', ms=10, mfc='#009988', label= '증가' )
plt.xlabel('연도')
plt.ylabel('증가치')
plt.show()
# Out:
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51613 (\N{HANGUL SYLLABLE JEUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ### 차트 그림의 구조
# matplotlib으로 그려지는 차트는 Figure 객체, Axes 객체, Axis 객체로 구성이 되어져있음
# `Fiqure` 객체는 하나 이상의 Axes 객체를 포함하고 있고, Axes 객체는 두 개 이상의 Axis 객체를 포함하고 있음
#
# - `Figure`: 차트가 그려지는 캔버스
# - `Axes`: 하나의 Plot (그래프)
# - `Axis`: 하나의 축(가로축, 세로축 등)

# %% [markdown]
# #### `Figure` 객체
# 모든 차트 그래프는 결과는 Figure 객체에 포함되어 있음
# 내부 차트가 아닌 경우 하나의 Figure 객체에는 하나의 아이디와 윈도우를 가짐
# 일반적으로 기본 파이썬에서 차트를 표시하면 Figure 하나당 하나의 윈도우를 가짐
# `plot()` 메서드가 자동으로 Figure 객체를 생성하기 때문에 직접 생성하는 경우는 드물지만 여러 개의 윈도우를 동시에 출력할 때나 차트 전체의 크기를 변경하고 싶을 때 사용할 수 있음

# %%
# figure는 캔버스나 종이를 뜻함
# figure메서드의 figsize 인수로 사이즈 지정
f1 = plt.figure(figsize = (10, 2))
plt.title('figure 객체 사이즈 변경')
# 해당 차트의 데이터를 랜덤 정수인 난수로 생성.
plt.plot(np.random.randn(100))
plt.show()
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44061 (\N{HANGUL SYLLABLE GAEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# 현재 사용하고 있는 Figure의 객체를 얻으려면 `gcf()`메서드로 얻을 수 있음

# %%
#  figure사이즈 10, 2지정, 데이터를 랜덤 정수인 난수 100이하로 지정.
# figure는 matplotlib.figure.Figure 클래스에 포함되어 있아, 내부(inline) 플롯이 아닌 하나의 아이디 숫자와 윈도우를 가진다.
f1 = plt.figure(figsize = (10, 2))
plt.title('figure 객체 사이즈 변경')
plt.plot(np.random.randn(100))
# f2는 f1, f2의 데이터값을 수치화한걸 시각화 한다.
f2 = plt.gcf()
print(id(f1))
print(id(f2))
plt.show()

plt.title('figure1 객체 사이즈 변경')
plt.plot(np.random.randn(20))

f3 = plt.gcf()
print(id(f3))
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# 1867500944464
# 1867500944464
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 44061 (\N{HANGUL SYLLABLE GAEG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   func(*args, **kwargs)
# ...

# %% [markdown]
# ### `Axes`객체와 `subplot`
# 하나의 `Figure`객체 안에 여러개의 Axes 객체를 생성하여 행렬 형태의 `서브 플롯`을 생성할 수 있다
# 이때 `subplot()` 메서드를 사용하여 명시적으로 Axes 객체를 생성할 수 있음
# 그러나, `pyplot`의 `plot()` 메서드를 바로 사용해도 Axes객체를 생성할 수 있음

# %%
x1 = np.linspace(0, 5)  # 0~5
x2 = np.linspace(0, 2) # 0~2
y1 = np.cos(2*np.pi*x1) * np.exp(-x1)
y2 = np.cos(2*np.pi*x2)

# subplot(nrows, ncoulmns, index)순서임.
plt.subplot(2, 1, 1) # 2행 1열 첫번째 인덱스니까, 위로 위치함
plt.plot(x1, y1, 'yo-') # x1, y1을 시각화하고, y는 yello색상, o는 원모양 마커, -는 실선으로 지정
plt.title('2행 1열 서브 플롯 첫 번째')

plt.subplot(2, 1, 2) # 2행 1열 두 번째 인덱스이므로 밑에 위치함.
plt.plot(x2, y2, 'r.-') # x2, y2 시각화, r은 red색상, . 모양의 마커, - 실선으로 지정 
plt.title('2행  1열 서브 플롯 두 번째')

plt.tight_layout() #  코드 출력시 두개의 차트가 출력 되는데 대신 타이틀이 겹쳐져서,  해당 코드로 공백을 준다.
plt.show()
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_8436\1828642927.py:15: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   plt.tight_layout() #  코드 출력시 두개의 차트가 출력 되는데 대신 타이틀이 겹쳐져서,  해당 코드로 공백을 준다.
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_8436\1828642927.py:15: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   plt.tight_layout() #  코드 출력시 두개의 차트가 출력 되는데 대신 타이틀이 겹쳐져서,  해당 코드로 공백을 준다.
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_8436\1828642927.py:15: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   plt.tight_layout() #  코드 출력시 두개의 차트가 출력 되는데 대신 타이틀이 겹쳐져서,  해당 코드로 공백을 준다.
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_8436\1828642927.py:15: UserWarning: Glyph 48652 (\N{HANGUL SYLLABLE BEU}) missing from current font.
#   plt.tight_layout() #  코드 출력시 두개의 차트가 출력 되는데 대신 타이틀이 겹쳐져서,  해당 코드로 공백을 준다.
# ...

# %% [markdown]
# `subplot()` 메서드의 (x, y, index)의 인수를 (xyindex)로 붙여서 사용할 수 있음
# 예시: `subplot(2, 2, 1)` -> `subplot(221)`

# %%
# subplot()메서드에 221은 2, 2, 1이란 뜻.
plt.subplot(221)    # x, y, index
plt.plot(np.random.rand(5)) # 5이하의 랜덤 난수
plt.title('첫 번째 플롯')

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title('두 번째 플롯')

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title('세 번째 플롯')

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title('네 번째 플롯')

plt.tight_layout()
plt.show()
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_8436\1254523785.py:18: UserWarning: Glyph 52395 (\N{HANGUL SYLLABLE CEOS}) missing from current font.
#   plt.tight_layout()
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_8436\1254523785.py:18: UserWarning: Glyph 48264 (\N{HANGUL SYLLABLE BEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_8436\1254523785.py:18: UserWarning: Glyph 51704 (\N{HANGUL SYLLABLE JJAE}) missing from current font.
#   plt.tight_layout()
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_8436\1254523785.py:18: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from current font.
#   plt.tight_layout()
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_8436\1254523785.py:18: UserWarning: Glyph 47215 (\N{HANGUL SYLLABLE ROS}) missing from current font.
#   plt.tight_layout()
# findfont: Font family 'NanumGothic' not found.
# ...

# %% [markdown]
# `subplot(x, y)` 메서드로 복수의 axes 객체를 담은 배열을 생성할 수 있음
# `subplot(x, y)` 메서드는 `(figure, axes 배열)` 튜플을 반환
# axes는 두개 이상의 axis를 객체를 포함

# %%
figure, axes = plt.subplots(2, 2)   # plt.subplots(2, 2) = 2행 2열이란 뜻이고, 차트가  2행 2열인 4개가 생성된다.

axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title('1행 1열')

axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title('1행 2열')

axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title('2행 1열')

axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title('2행 2열')

plt.tight_layout() # 타이틀 제목과 차트가 겹치지 않게
plt.show()
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_8436\770936615.py:15: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   plt.tight_layout() # 타이틀 제목과 차트가 겹치지 않게
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_8436\770936615.py:15: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   plt.tight_layout() # 타이틀 제목과 차트가 겹치지 않게
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# ...

# %% [markdown]
# #### Axis 객체와 축
# `twinx()` 메서드로 x축을 공유하는 새로운 Axes 객체를 생성할 수 있음
# (즉 a, b 2개의 차트를 사용하는데 a차트의 x축범위를 b가 같이 사용할수 있게 공유해주는 것 )
# 그럼 a의 차트를 만들고, b의 차트를 만들 때 x축 범위를 따로 지정하지 않아도 되서 y축 범위만 지정해주면 됨.

# %%
figure, axes0 = plt.subplots()
# twinx: x축을 공유하는 플롯
axes1 = axes0.twinx()

axes0.set_title('x축을 공유하는 플롯')
axes0.plot([10, 5, 2, 9, 7], 'r-', label='y0')
axes0.set_ylabel('y0')

axes1.plot([100, 200, 210, 180, 120], 'g:', label='y1')
axes1.set_ylabel('y1')

axes0.set_xlabel('x축')

plt.show()
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51012 (\N{HANGUL SYLLABLE EUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ITPS\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54616 (\N{HANGUL SYLLABLE HA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
